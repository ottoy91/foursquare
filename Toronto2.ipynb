# %%
# !conda install -c conda-forge geocoder --yes
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
#import geocoder # import geocoder
# initialize your variable to None
import geocoder
geocoder.google('Mountain View, CA')
# Out:
# <[REQUEST_DENIED] Google - Geocode [empty]>

# %%
import pandas as pd
#loading coordinates manually from csv-file\ncoord = pd.read_csv(r"Geospatial_Coordinates.csv") 

coord.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
#load the neighborhoods from previously created file and drop unnecessry column
hoods = pd.read_csv(r"hoods.csv") 
hoods.drop('Unnamed: 0', axis=1, inplace=True)
hoods = hoods[['Postal Code', 'Borough', 'Neighborhood']]
hoods
# Out:
#   Postal Code           Borough  \
# 0         M4N   Central Toronto
# 1         M4W  Downtown Toronto
# 2         M4E      East Toronto
# 3         M4B         East York
# 4         M8V         Etobicoke
# 5         M7R       Mississauga
# 6         M2H        North York
# 7         M1B       Scarborough
# 8         M6H      West Toronto
# 9         M6C              York
#
#                                         Neighborhood
# 0  Lawrence Park, Davisville North, North Toronto...
# 1  Rosedale, St. James Town, Cabbagetown, Church ...
# 2  The Beaches, The Danforth West, Riverdale, Ind...
# 3  Parkview Hill, Woodbine Gardens, Woodbine Heig...
# 4  New Toronto, Mimico South, Humber Bay Shores, ...
# 5              Canada Post Gateway Processing Centre
# 6  Hillcrest Village, Fairview, Henry Farm, Oriol...
# 7  Malvern, Rouge, Rouge Hill, Port Union, Highla...
# 8  Dufferin, Dovercourt Village, Little Portugal,...
# 9  Humewood-Cedarvale, Caledonia-Fairbanks, Del R...

# %%
#merge the two files based on common postal code value
newfile = pd.merge(hoods,coord,on='Postal Code')
newfile
# Out:
#   Postal Code           Borough  \
# 0         M4N   Central Toronto
# 1         M4W  Downtown Toronto
# 2         M4E      East Toronto
# 3         M4B         East York
# 4         M8V         Etobicoke
# 5         M7R       Mississauga
# 6         M2H        North York
# 7         M1B       Scarborough
# 8         M6H      West Toronto
# 9         M6C              York
#
#                                         Neighborhood   Latitude  Longitude
# 0  Lawrence Park, Davisville North, North Toronto...  43.728020 -79.388790
# 1  Rosedale, St. James Town, Cabbagetown, Church ...  43.679563 -79.377529
# 2  The Beaches, The Danforth West, Riverdale, Ind...  43.676357 -79.293031
# 3  Parkview Hill, Woodbine Gardens, Woodbine Heig...  43.706397 -79.309937
# 4  New Toronto, Mimico South, Humber Bay Shores, ...  43.605647 -79.501321
# 5              Canada Post Gateway Processing Centre  43.636966 -79.615819
# 6  Hillcrest Village, Fairview, Henry Farm, Oriol...  43.803762 -79.363452
# ...
